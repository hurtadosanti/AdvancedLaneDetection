# %%
import cv2
import numpy as np
import thresholds
import matplotlib.pyplot as plt

#ignore_mask_color=255
def get_interest_region(image,mask,ignore_mask_color,threshold):
    edges = cv2.Canny(image, threshold[0], threshold[1])
    mask = np.zeros_like(mask)
    # This time we are defining a four sided polygon to mask
    shape = image.shape
    vertices = np.array([[(50,shape[0]),(500, 400), (shape[1]-500, 400), (shape[1],shape[0])]], dtype=np.int32)
    cv2.fillPoly(mask, vertices, ignore_mask_color)
    return cv2.bitwise_and(edges,mask)

# %%
img = cv2.imread('./test_images/test1.jpg')
color, combined = thresholds.highlight_features(img)
#plt.imshow(get_interest_region(img,combined,255,(100,250)),cmap="gray")
plt.imshow(combined,cmap="gray")

# %%
img = cv2.imread('./test_images/test1.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

abs = thresholds.abs_sobel_thresh(gray,'x',5,(30,100))

plt.imshow(abs,cmap="gray")
